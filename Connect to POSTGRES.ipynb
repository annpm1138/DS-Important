# %%
# !pip install ipython-sql
# Out:
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=6ac17b4325ba6b028071da1f39e7438e1c2df5e78551a10297653f0939a6be77
#   Stored in directory: c:\users\pc-3\appdata\local\pip\cache\wheels\75\f7\28\77a076f1fa8cbeda61aca712815d04d7a32435f04a26a2dd7b
# Successfully built prettytable
# ...

# %%
# !pip install sqlalchemy

# %%
# !pip install psycopg2

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine

# %%
# %sql postgresql://postgres:Admin123@localhost/CMDashboard

# %%
# %%sql
# SELECT *
# FROM jjm.awc_details
# LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/CMDashboard
# 5 rows affected.
# [(1, 70152, 2357371, -1, '', 'Dariullarpar', 'Govt. Aided', 'Balwadi/Aganwadi', 92, '0', '', 'No', '', 0, 0, 'No', 'No', 'No', '26.28470460', '89.80444261', 'No', 'No', 'No', 'Yes', datetime.datetime(2022, 2, 21, 0, 0), datetime.datetime(2022, 2, 21, 0, 0)),
#  (2, 70152, 2357395, -1, '', 'Daspara ', 'Govt. Aided', 'Balwadi/Aganwadi', 105, '0', '', 'No', '', 0, 0, 'No', 'No', 'No', '26.28560883', '89.80435678', 'No', 'No', 'No', 'Yes', datetime.datetime(2022, 2, 21, 0, 0), datetime.datetime(2022, 2, 21, 0, 0)),
#  (3, 70152, 2357418, -1, '', 'Shaluk Kurarpar', 'Govt. Aided', 'Balwadi/Aganwadi', 117, '0', '', 'No', '', 0, 0, 'No', 'No', 'No', '26.27608519', '89.80688878', 'No', 'No', 'No', 'Yes', datetime.datetime(2022, 2, 21, 0, 0), datetime.datetime(2022, 2, 21, 0, 0)),
# ...

# %%
# Format
#engine = create_engine('dialect+driver://username:password@host:port/database')
# Example format
engine = create_engine('postgresql://postgres:Admin123@localhost/CMDashboard')

# %%
import pandas as pd

# %%
df = pd.read_sql('SELECT * FROM jjm.awc_details LIMIT 5', engine)

# %%
df
# Out:
#    id  habitation_id   awc_id  scheme_id scheme_name  \
# 0   1          70152  2357371         -1
# 1   2          70152  2357395         -1
# 2   3          70152  2357418         -1
# 3   4          70152  2357439         -1
# 4   5          70152  2357456         -1
#
#                         name classification          category  noof_students  \
# 0               Dariullarpar    Govt. Aided  Balwadi/Aganwadi             92
# 1                   Daspara     Govt. Aided  Balwadi/Aganwadi            105
# 2            Shaluk Kurarpar    Govt. Aided  Balwadi/Aganwadi            117
# 3  Saluk Kurarpar Pachim (M)    Govt. Aided  Balwadi/Aganwadi             89
# 4       Dariullarpar Pub( M)    Govt. Aided  Balwadi/Aganwadi             73
#
#   whether_it_is_residential  ... running_water_in_toilet_urinals  \
# 0                         0  ...                              No
# 1                         0  ...                              No
# ...
